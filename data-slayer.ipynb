# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import Data

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
df_sample = pd.read_csv('sample_submission.csv')
df_train.head()
# Out:
#    Id    Make            Vehicle Class Engine Size(L) Cylinders Transmission  \
# 0   1    FOLD  PICKUP TRUCK - STANDARD            3.5       6.0           A6
# 1   2   CHEVO  PICKUP TRUCK - STANDARD            5.3       NaN           A6
# 2   3     BMV               SUBCOMPACT            4.4       NaN           M6
# 3   4     KIO              SUV - SMALL            NaN       4.0          AS6
# 4   5  BARUSU              MINICOMPACT            3.0       6.0  unspecified
#
#   Fuel Type    Fuel Consumption City     Fuel Consumption Hwy  \
# 0         X   8.64 liters per 100 km            6.14 L/100 km
# 1         E  27.27 liters per 100 km  30.76 liters per 100 km
# 2         Z              0.17 L/10km   2.03 liters per 100 km
# 3         X            6.52 km per L              1.59 L/10km
# 4         Z            20.15 L/100km              0.60 L/10km
#
#   Fuel Consumption Comb  CO2 Emissions(g/km)
# 0        37.59 mpg Imp.                306.0
# 1        28.84 L/100 km                283.0
# 2                  zero                329.0
# 3                   NaN                270.0
# 4           1.38 L/10km                193.0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137141 entries, 0 to 137140
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Id                     137141 non-null  int64
#  1   Make                   137141 non-null  object
#  2   Vehicle Class          135816 non-null  object
#  3   Engine Size(L)         120522 non-null  object
#  4   Cylinders              122986 non-null  object
#  5   Transmission           134536 non-null  object
#  6   Fuel Type              135286 non-null  object
#  7   Fuel Consumption City  134719 non-null  object
#  8   Fuel Consumption Hwy   134573 non-null  object
#  9   Fuel Consumption Comb  134559 non-null  object
#  10  CO2 Emissions(g/km)    137141 non-null  float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 11.5+ MB

# %% [markdown]
# # Data Cleaning

# %%
check_null = df_train.isnull()

for i in check_null.columns.tolist():
    print(check_null[i].value_counts())
    print('')
# Out:
# False    137141
# Name: Id, dtype: int64
#
# False    137141
# Name: Make, dtype: int64
#
# False    135816
# True       1325
# Name: Vehicle Class, dtype: int64
#
# False    120522
# True      16619
# Name: Engine Size(L), dtype: int64
#
# False    122986
# True      14155
# Name: Cylinders, dtype: int64
#
# False    134536
# True       2605
# Name: Transmission, dtype: int64
#
# False    135286
# True       1855
# Name: Fuel Type, dtype: int64
#
# False    134719
# True       2422
# Name: Fuel Consumption City, dtype: int64
#
# False    134573
# True       2568
# Name: Fuel Consumption Hwy, dtype: int64
#
# False    134559
# True       2582
# Name: Fuel Consumption Comb, dtype: int64
#
# False    137141
# Name: CO2 Emissions(g/km), dtype: int64

# %%
df_train.describe(include='object').T
# Out:
#                         count unique            top   freq
# Make                   137141     21           FOLD  18081
# Vehicle Class          135816     24    SUV - SMALL  27799
# Engine Size(L)         120522     50            2.0  21216
# Cylinders              122986     15            4.0  66618
# Transmission           134536     33            AS6  28926
# Fuel Type              135286     13              X  83001
# Fuel Consumption City  134719  33648              0    639
# Fuel Consumption Hwy   134573  34963           zero    672
# Fuel Consumption Comb  134559  26157  not-available    695

# %%
df_train['numeric_FuelCity'] = df_train['Fuel Consumption City'].str.extract(r'([\d.]+)').astype(float)
df_train['MeasureUnit_FuelCity'] = df_train['Fuel Consumption City'].str.extract(r'\s(.+)')

df_train.sample(3)
# Out:
#             Id     Make Vehicle Class Engine Size(L) Cylinders Transmission  \
# 36441    36442     JIPU   SUV - SMALL            2.4       4.0           A6
# 39054    39055     FOLD           NaN            1.5       4.0          AS6
# 115811  115812  RYUNDAI     FULL-SIZE            NaN       8.0          AS8
#
#        Fuel Type Fuel Consumption City Fuel Consumption Hwy  \
# 36441          X         8.67 km per L           13.78 km/L
# 39054          X         4.26 MPG (AS)        7.17 km per L
# 115811         Z          3.59 L/100km        0.12 L/100 km
#
#        Fuel Consumption Comb  CO2 Emissions(g/km)  numeric_FuelCity  \
# 36441                    NaN                253.0              8.67
# 39054          36.65 L/100km                182.0              4.26
# 115811           0.20 L/10km                308.0              3.59
#
#        MeasureUnit_FuelCity
# 36441              km per L
# 39054              MPG (AS)
# 115811              L/100km

# %%
df_train.head(3)
# Out:
#    Id   Make            Vehicle Class Engine Size(L) Cylinders Transmission  \
# 0   1   FOLD  PICKUP TRUCK - STANDARD            3.5       6.0           A6
# 1   2  CHEVO  PICKUP TRUCK - STANDARD            5.3       NaN           A6
# 2   3    BMV               SUBCOMPACT            4.4       NaN           M6
#
#   Fuel Type    Fuel Consumption City     Fuel Consumption Hwy  \
# 0         X   8.64 liters per 100 km            6.14 L/100 km
# 1         E  27.27 liters per 100 km  30.76 liters per 100 km
# 2         Z              0.17 L/10km   2.03 liters per 100 km
#
#   Fuel Consumption Comb  CO2 Emissions(g/km)  numeric_FuelCity  \
# 0        37.59 mpg Imp.                306.0              8.64
# 1        28.84 L/100 km                283.0             27.27
# 2                  zero                329.0              0.17
#
#   MeasureUnit_FuelCity
# 0    liters per 100 km
# 1    liters per 100 km
# 2               L/10km

# %% [markdown]
# ## General

# %%
df_train['Fuel Consumption City'].value_counts()
# Out:
# 0                  639
# not-available      624
# -9999              617
# -1                 604
# zero               599
#                   ...
# 75.92 km per L       1
# 46.42 MPG (AS)       1
# 181.27 MPG (AS)      1
# 58.68 mpg Imp.       1
# 33.71 L/100 km       1
# Name: Fuel Consumption City, Length: 33648, dtype: int64

# %%
df_train['Fuel Consumption Hwy'].value_counts()
# Out:
# zero                       672
# 9999                       669
# -9999                      660
# not-available              647
# -1                         644
#                           ...
# 65.19 mpg Imp.               1
# 85.28 km/L                   1
# 133.13 km/L                  1
# 33.92 liters per 100 km      1
# 1275.84 mpg Imp.             1
# Name: Fuel Consumption Hwy, Length: 34963, dtype: int64

# %%
df_train['Fuel Consumption Comb'].value_counts()
# Out:
# not-available      695
# zero               681
# -9999              665
# -1                 637
# 9999               617
#                   ...
# 7.80 mpg Imp.        1
# 118.13 mpg Imp.      1
# 51.68 MPG (AS)       1
# 69.35 MPG (AS)       1
# 32.27 km per L       1
# Name: Fuel Consumption Comb, Length: 26157, dtype: int64

# %%
df_train[df_train['Fuel Consumption Comb'] == '-9999']
# Out:
#             Id      Make            Vehicle Class Engine Size(L) Cylinders  \
# 9           10   FOLKSWA                  COMPACT            2.0       4.0
# 42          43      FOLD  PICKUP TRUCK - STANDARD            3.5       6.0
# 349        350      JIPU              SUV - SMALL             na       6.0
# 732        733     MITSU              SUV - SMALL            2.4       4.0
# 1411      1412    NIRRAN                 MID-SIZE            2.5       4.0
# ...        ...       ...                      ...            ...       ...
# 135362  135363   LAMBOGI               TWO-SEATER            NaN      10.0
# 135373  135374     LECUS              SUV - SMALL            2.0       4.0
# 135877  135878  CADILUXE                 MID-SIZE            NaN       8.0
# 136152  136153     CHEVO                  COMPACT            1.8       4.0
# 136874  136875      FOLD  PICKUP TRUCK - STANDARD            3.3       NaN
#
#        Transmission Fuel Type Fuel Consumption City     Fuel Consumption Hwy  \
# 9               AS6         X        43.84 km per L           18.13 L/100 km
# 42              AS6         X        14.09 L/100 km            6.73 L/100 km
# 349              M5         X         7.88 mpg Imp.           16.98 MPG (AS)
# 732             AV6         X         8.11 km per L             5.60 L/100km
# 1411             M6         X        52.45 mpg Imp.               50.74 km/L
# ...             ...       ...                   ...                      ...
# 135362          AM7         Z        12.87 L/100 km             5.32 L/100km
# 135373          AS6         Z        10.62 MPG (AS)           35.44 MPG (AS)
# 135877          AS8         Z        18.69 km per L  12.33 liters per 100 km
# 136152          AS6         X          0.26 L/100km           22.72 MPG (AS)
# 136874          AS6         X        41.58 mpg Imp.           17.13 L/100 km
#
#        Fuel Consumption Comb  CO2 Emissions(g/km)  numeric_FuelCity  \
# 9                      -9999           202.000000             43.84
# 42                     -9999           282.000000             14.09
# 349                    -9999           215.000000              7.88
# 732                    -9999           216.000000              8.11
# 1411                   -9999           197.000000             52.45
# ...                      ...                  ...               ...
# 135362                 -9999           615.131491             12.87
# 135373                 -9999           216.000000             10.62
# 135877                 -9999           408.000000             18.69
# 136152                 -9999           199.000000              0.26
# 136874                 -9999           292.000000             41.58
#
#        MeasureUnit_FuelCity
# 9                  km per L
# 42                 L/100 km
# 349                mpg Imp.
# 732                km per L
# 1411               mpg Imp.
# ...                     ...
# 135362             L/100 km
# 135373             MPG (AS)
# 135877             km per L
# 136152              L/100km
# 136874             mpg Imp.
#
# [665 rows x 13 columns]

# %%
df_train[df_train['Fuel Consumption Hwy'] == '-9999']
# Out:
#             Id     Make    Vehicle Class Engine Size(L) Cylinders  \
# 50          51    LECUS       SUBCOMPACT            3.5       6.0
# 99         100    CHEVO  VAN - PASSENGER            4.8       8.0
# 389        390  LAMBOGI       TWO-SEATER            5.2      10.0
# 733        734    CHEVO      SUV - SMALL            NaN       4.0
# 773        774     DOGE        FULL-SIZE            3.6       6.0
# ...        ...      ...              ...            ...       ...
# 136563  136564  MATSUDA         MID-SIZE            2.0       4.0
# 136820  136821  FOLKSWA         MID-SIZE        missing       6.0
# 137016  137017   BARUSU          COMPACT            2.5       4.0
# 137062  137063      BMV       TWO-SEATER            3.0       NaN
# 137123  137124     FOLD      SUV - SMALL            3.5       6.0
#
#        Transmission Fuel Type    Fuel Consumption City Fuel Consumption Hwy  \
# 50              AS6         Z            4.03 MPG (AS)                -9999
# 99               A6         X            4.32 km per L                -9999
# 389             AM7         Z           52.49 MPG (AS)                -9999
# 733              A6         X           18.57 L/100 km                -9999
# 773              A5         X              1.08 L/10km                -9999
# ...             ...       ...                      ...                  ...
# 136563           M6         X           15.63 L/100 km                -9999
# 136820          AS6         X            16.91 L/100km                -9999
# 137016           M6         Z  22.11 liters per 100 km                -9999
# 137062           M6         Z           29.64 L/100 km                -9999
# 137123          AS6         X               11.51 km/L                -9999
#
#           Fuel Consumption Comb  CO2 Emissions(g/km)  numeric_FuelCity  \
# 50                5.69 MPG (AS)                259.0              4.03
# 99      22.70 liters per 100 km                374.0              4.32
# 389              20.79 km per L                349.0             52.49
# 733                   7.63 km/L                207.0             18.57
# 773                 1.07 L/10km                276.0              1.08
# ...                         ...                  ...               ...
# 136563            8.69 L/100 km                177.0             15.63
# 136820                3.89 km/L                199.0             16.91
# 137016           14.65 L/100 km                287.0             22.11
# 137062           17.95 L/100 km                255.0             29.64
# 137123           41.70 MPG (AS)                252.0             11.51
#
#        MeasureUnit_FuelCity
# 50                 MPG (AS)
# 99                 km per L
# 389                MPG (AS)
# 733                L/100 km
# 773                  L/10km
# ...                     ...
# 136563             L/100 km
# 136820              L/100km
# 137016    liters per 100 km
# 137062             L/100 km
# 137123                 km/L
#
# [660 rows x 13 columns]

# %%
df_train[df_train['Fuel Consumption City'] == '-1']
# Out:
#             Id      Make            Vehicle Class Engine Size(L) Cylinders  \
# 33          34       KIO                  COMPACT            2.0       4.0
# 203        204    BARUSU              SUV - SMALL            2.0       4.0
# 274        275     CHEVO              SUV - SMALL            2.5       4.0
# 420        421    NIRRAN     PICKUP TRUCK - SMALL            2.5       4.0
# 567        568       BMV               SUBCOMPACT            2.0       4.0
# ...        ...       ...                      ...            ...       ...
# 135088  135089      JIPU              SUV - SMALL            1.4       NaN
# 135875  135876     CHEVO  PICKUP TRUCK - STANDARD            5.3       8.0
# 136025  136026      FOLD               SUBCOMPACT            NaN       4.0
# 136371  136372      FIAR    STATION WAGON - SMALL            1.4       4.0
# 137053  137054  CADILUXE                  COMPACT            NaN       8.0
#
#         Transmission Fuel Type Fuel Consumption City Fuel Consumption Hwy  \
# 33               AS6         X                    -1       14.88 km per L
# 203              AV8       NaN                    -1       17.43 MPG (AS)
# 274              AS6         X                    -1          0.33 L/10km
# 420               A5         X                    -1       13.71 km per L
# 567               M6         Z                    -1         4.01 L/100km
# ...              ...       ...                   ...                  ...
# 135088            M6         X                    -1       52.44 MPG (AS)
# 135875            A6         X                    -1        8.93 km per L
# 136025  not-recorded         X                    -1          1.19 L/10km
# 136371           AM6         X                    -1        9.07 L/100 km
# 137053           AS6         X                    -1        4.31 L/100 km
#
#           Fuel Consumption Comb  CO2 Emissions(g/km)  numeric_FuelCity  \
# 33                           -1           213.000000               1.0
# 203                 0.89 L/10km           198.000000               1.0
# 274                 0.69 L/10km           183.000000               1.0
# 420               7.44 km per L           303.000000               1.0
# 567                  49.73 km/L           207.000000               1.0
# ...                         ...                  ...               ...
# 135088              0.82 L/10km           290.435201               1.0
# 135875  12.83 liters per 100 km           289.000000               1.0
# 136025                        0           194.000000               1.0
# 136371            14.29 L/100km           203.000000               1.0
# 137053               34.34 km/L           254.000000               1.0
#
#        MeasureUnit_FuelCity
# 33                      NaN
# 203                     NaN
# 274                     NaN
# 420                     NaN
# 567                     NaN
# ...                     ...
# 135088                  NaN
# 135875                  NaN
# 136025                  NaN
# 136371                  NaN
# 137053                  NaN
#
# [604 rows x 13 columns]

# %%
df_train[df_train['Fuel Consumption City'] == 'not-available']
# Out:
#             Id    Make          Vehicle Class Engine Size(L) Cylinders  \
# 344        345     KIO  STATION WAGON - SMALL            NaN       4.0
# 434        435  TOYOTI   PICKUP TRUCK - SMALL            3.5       6.0
# 467        468    DOGE               MID-SIZE            6.4       NaN
# 637        638    JIPU            SUV - SMALL            2.4       4.0
# 831        832     BMV               MID-SIZE            3.0       NaN
# ...        ...     ...                    ...            ...       ...
# 135530  135531     BMV                COMPACT            2.0       4.0
# 135534  135535   TOLVO            SUV - SMALL            3.2       6.0
# 136019  136020   CHEVO              FULL-SIZE            3.6       6.0
# 136109  136110   ASURA                COMPACT            3.5       6.0
# 136910  136911    FOLD                COMPACT            2.0       4.0
#
#         Transmission    Fuel Type Fuel Consumption City  \
# 344              AS6            X         not-available
# 434              AS6            X         not-available
# 467               M6            Z         not-available
# 637               A9            X         not-available
# 831              AS8            Z         not-available
# ...              ...          ...                   ...
# 135530           AS8            Z         not-available
# 135534           AS6  unspecified         not-available
# 136019           AS6            X         not-available
# 136109  not-recorded            Z         not-available
# 136910            M5            E         not-available
#
#            Fuel Consumption Hwy Fuel Consumption Comb  CO2 Emissions(g/km)  \
# 344              11.26 L/100 km                  zero                213.0
# 434              12.89 mpg Imp.           2.28 L/10km                273.0
# 467               10.75 L/100km             5.12 km/L                311.0
# 637              25.05 mpg Imp.             6.52 km/L                234.0
# 831                 0.26 L/10km        11.22 km per L                223.0
# ...                         ...                   ...                  ...
# 135530            14.86 L/100km          7.49 L/100km                209.0
# 135534           57.16 MPG (AS)        33.10 mpg Imp.                244.0
# 136019               11.12 km/L        11.81 MPG (AS)                246.0
# 136109  12.77 liters per 100 km            13.94 km/L                230.0
# 136910           22.22 L/100 km        17.67 MPG (AS)                154.0
#
#         numeric_FuelCity MeasureUnit_FuelCity
# 344                  NaN                  NaN
# 434                  NaN                  NaN
# 467                  NaN                  NaN
# 637                  NaN                  NaN
# 831                  NaN                  NaN
# ...                  ...                  ...
# 135530               NaN                  NaN
# 135534               NaN                  NaN
# 136019               NaN                  NaN
# 136109               NaN                  NaN
# 136910               NaN                  NaN
#
# [624 rows x 13 columns]

# %% [markdown]
# as we can see that column that has -9999 / -1 / zero / not-available has information from other column that we can use to find that value with the information that
#
# > column 'Fuel Consumption Comb' is combined fuel consumption rating, calculated as a blend of 55% city driving and 45% highway driving.
#
# So that mean we have the calculation of \
# **Combined Fuel Consumption=(City Consumption×0.55t)+(Highway Consumption×0.45)**

# %% [markdown]
# But first, that means we need to separate each column to numeric

# %% [markdown]
# ## Fuel Consumption Column Preprocessing

# %%
df_train['numeric_FuelCity'] = df_train['Fuel Consumption City'].str.extract(r'([\d.]+)').astype(float)
df_train['MeasureUnit_FuelCity'] = df_train['Fuel Consumption City'].str.extract(r'\s(.+)')

# %%
df_train['numeric_FuelHwy'] = df_train['Fuel Consumption Hwy'].str.extract(r'([\d.]+)').astype(float)
df_train['MeasureUnit_FuelHwy'] = df_train['Fuel Consumption Hwy'].str.extract(r'\s(.+)')

# %%
df_train['numeric_FuelComb'] = df_train['Fuel Consumption Comb'].str.extract(r'([\d.]+)').astype(float)
df_train['MeasureUnit_FuelComb'] = df_train['Fuel Consumption Comb'].str.extract(r'\s(.+)')

# %%
df_train.sample(5)
# Out:
#             Id    Make            Vehicle Class Engine Size(L) Cylinders  \
# 100168  100169  TOYOTI                 MID-SIZE             na       4.0
# 82806    82807    DOGE                  MINIVAN            NaN       6.0
# 46152    46153     BMV               SUBCOMPACT            3.0       NaN
# 31622    31623   CHEVO  PICKUP TRUCK - STANDARD            NaN       8.0
# 66522    66523  NIRRAN              SUV - SMALL            1.8       4.0
#
#        Transmission Fuel Type    Fuel Consumption City  \
# 100168          AS8         X           14.84 MPG (AS)
# 82806            A6         E           80.17 mpg Imp.
# 46152           AS8         Z             2.87 L/100km
# 31622            A6         X  14.26 liters per 100 km
# 66522            AV        na           28.83 L/100 km
#
#           Fuel Consumption Hwy    Fuel Consumption Comb  CO2 Emissions(g/km)  \
# 100168           3.78 L/100 km           10.42 L/100 km                179.0
# 82806           31.65 MPG (AS)           18.93 km per L                267.0
# 46152           20.46 L/100 km           21.81 MPG (AS)                218.0
# 31622   5.80 liters per 100 km  10.45 liters per 100 km                321.0
# 66522            2.82 L/100 km  17.12 liters per 100 km                261.0
#
#         numeric_FuelCity MeasureUnit_FuelCity  numeric_FuelHwy  \
# 100168             14.84             MPG (AS)             3.78
# 82806              80.17             mpg Imp.            31.65
# 46152               2.87              L/100km            20.46
# 31622              14.26    liters per 100 km             5.80
# 66522              28.83             L/100 km             2.82
#
#        MeasureUnit_FuelHwy  numeric_FuelComb MeasureUnit_FuelComb
# 100168            L/100 km             10.42             L/100 km
# 82806             MPG (AS)             18.93             km per L
# 46152             L/100 km             21.81             MPG (AS)
# 31622    liters per 100 km             10.45    liters per 100 km
# 66522             L/100 km             17.12    liters per 100 km

# %%
df_train['MeasureUnit_FuelCity'].value_counts()
# Out:
# L/10km               16614
# L/100km              16612
# km per L             16600
# km/L                 16408
# L/100 km             16363
# mpg Imp.             16308
# liters per 100 km    16098
# MPG (AS)             16090
# Name: MeasureUnit_FuelCity, dtype: int64

# %%
df_train['MeasureUnit_FuelHwy'].value_counts()
# Out:
# km/L                 16502
# mpg Imp.             16365
# MPG (AS)             16365
# L/10km               16346
# L/100 km             16312
# km per L             16299
# L/100km              16265
# liters per 100 km    16199
# Name: MeasureUnit_FuelHwy, dtype: int64

# %%
df_train['MeasureUnit_FuelComb'].value_counts()
# Out:
# MPG (AS)             16458
# km/L                 16443
# L/100 km             16409
# L/100km              16357
# liters per 100 km    16305
# km per L             16278
# L/10km               16231
# mpg Imp.             16170
# Name: MeasureUnit_FuelComb, dtype: int64

# %% [markdown]
# So, I want to convert all the measure to km/L

# %% [markdown]
# ### Equation & Validation

# %%
df_checking = df_train.copy()

# %% [markdown]
# #### L/10km --> km/L

# %%
df_checking['numeric_FuelCity'] = np.where(df_train['MeasureUnit_FuelCity'] == 'L/10km', 
                                           10 / df_train['numeric_FuelCity'], df_train['numeric_FuelCity'])
df_checking[df_checking['MeasureUnit_FuelCity'] == 'L/10km'].head(3)
# Out:
#     Id    Make         Vehicle Class Engine Size(L) Cylinders Transmission  \
# 2    3     BMV            SUBCOMPACT            4.4       NaN           M6
# 12  13  TOYOTI               MINIVAN            2.0       4.0          AS6
# 26  27  NIRRAN  PICKUP TRUCK - SMALL            NaN       NaN           M6
#
#    Fuel Type Fuel Consumption City    Fuel Consumption Hwy  \
# 2          Z           0.17 L/10km  2.03 liters per 100 km
# 12         X           0.22 L/10km           5.30 L/100 km
# 26         X           0.53 L/10km  3.58 liters per 100 km
#
#    Fuel Consumption Comb  CO2 Emissions(g/km)  numeric_FuelCity  \
# 2                   zero                329.0         58.823529
# 12        27.94 km per L                260.0         45.454545
# 26        22.11 km per L                307.0         18.867925
#
#    MeasureUnit_FuelCity  numeric_FuelHwy MeasureUnit_FuelHwy  \
# 2                L/10km             2.03   liters per 100 km
# 12               L/10km             5.30            L/100 km
# 26               L/10km             3.58   liters per 100 km
#
#     numeric_FuelComb MeasureUnit_FuelComb
# 2                NaN                  NaN
# 12             27.94             km per L
# 26             22.11             km per L

# %%
df_train[df_train['MeasureUnit_FuelCity'] == 'L/10km'].head(3)
# Out:
#     Id    Make         Vehicle Class Engine Size(L) Cylinders Transmission  \
# 2    3     BMV            SUBCOMPACT            4.4       NaN           M6
# 12  13  TOYOTI               MINIVAN            2.0       4.0          AS6
# 26  27  NIRRAN  PICKUP TRUCK - SMALL            NaN       NaN           M6
#
#    Fuel Type Fuel Consumption City    Fuel Consumption Hwy  \
# 2          Z           0.17 L/10km  2.03 liters per 100 km
# 12         X           0.22 L/10km           5.30 L/100 km
# 26         X           0.53 L/10km  3.58 liters per 100 km
#
#    Fuel Consumption Comb  CO2 Emissions(g/km)  numeric_FuelCity  \
# 2                   zero                329.0              0.17
# 12        27.94 km per L                260.0              0.22
# 26        22.11 km per L                307.0              0.53
#
#    MeasureUnit_FuelCity  numeric_FuelHwy MeasureUnit_FuelHwy  \
# 2                L/10km             2.03   liters per 100 km
# 12               L/10km             5.30            L/100 km
# 26               L/10km             3.58   liters per 100 km
#
#     numeric_FuelComb MeasureUnit_FuelComb
# 2                NaN                  NaN
# 12             27.94             km per L
# 26             22.11             km per L

# %% [markdown]
# #### L/100km --> km/L

# %%
df_checking['numeric_FuelCity'] = np.where(df_train['MeasureUnit_FuelCity'] == 'L/100km', 
                                           100 / df_train['numeric_FuelCity'], df_train['numeric_FuelCity'])
df_checking[df_checking['MeasureUnit_FuelCity'] == 'L/100km'].head(3)
# Out:
#     Id    Make Vehicle Class Engine Size(L) Cylinders Transmission Fuel Type  \
# 4    5  BARUSU   MINICOMPACT            3.0       6.0  unspecified         Z
# 6    7   GONDA     FULL-SIZE            1.8       4.0          AV7         X
# 13  14    JIPU   SUV - SMALL        missing       6.0      unknown         X
#
#    Fuel Consumption City     Fuel Consumption Hwy Fuel Consumption Comb  \
# 4          20.15 L/100km              0.60 L/10km           1.38 L/10km
# 6           7.52 L/100km           14.76 mpg Imp.        12.75 L/100 km
# 13          9.06 L/100km  12.21 liters per 100 km             9.54 km/L
#
#     CO2 Emissions(g/km)  numeric_FuelCity MeasureUnit_FuelCity  \
# 4                 193.0          4.962779              L/100km
# 6                 174.0         13.297872              L/100km
# 13                308.0         11.037528              L/100km
#
#     numeric_FuelHwy MeasureUnit_FuelHwy  numeric_FuelComb MeasureUnit_FuelComb
# 4              0.60              L/10km              1.38               L/10km
# 6             14.76            mpg Imp.             12.75             L/100 km
# 13            12.21   liters per 100 km              9.54                 km/L

# %%
df_train[df_train['MeasureUnit_FuelCity'] == 'L/100km'].head(3)
# Out:
#     Id    Make Vehicle Class Engine Size(L) Cylinders Transmission Fuel Type  \
# 4    5  BARUSU   MINICOMPACT            3.0       6.0  unspecified         Z
# 6    7   GONDA     FULL-SIZE            1.8       4.0          AV7         X
# 13  14    JIPU   SUV - SMALL        missing       6.0      unknown         X
#
#    Fuel Consumption City     Fuel Consumption Hwy Fuel Consumption Comb  \
# 4          20.15 L/100km              0.60 L/10km           1.38 L/10km
# 6           7.52 L/100km           14.76 mpg Imp.        12.75 L/100 km
# 13          9.06 L/100km  12.21 liters per 100 km             9.54 km/L
#
#     CO2 Emissions(g/km)  numeric_FuelCity MeasureUnit_FuelCity  \
# 4                 193.0             20.15              L/100km
# 6                 174.0              7.52              L/100km
# 13                308.0              9.06              L/100km
#
#     numeric_FuelHwy MeasureUnit_FuelHwy  numeric_FuelComb MeasureUnit_FuelComb
# 4              0.60              L/10km              1.38               L/10km
# 6             14.76            mpg Imp.             12.75             L/100 km
# 13            12.21   liters per 100 km              9.54                 km/L

# %%
df_train.head()
# Out:
#    Id    Make            Vehicle Class Engine Size(L) Cylinders Transmission  \
# 0   1    FOLD  PICKUP TRUCK - STANDARD            3.5       6.0           A6
# 1   2   CHEVO  PICKUP TRUCK - STANDARD            5.3       NaN           A6
# 2   3     BMV               SUBCOMPACT            4.4       NaN           M6
# 3   4     KIO              SUV - SMALL            NaN       4.0          AS6
# 4   5  BARUSU              MINICOMPACT            3.0       6.0  unspecified
#
#   Fuel Type    Fuel Consumption City     Fuel Consumption Hwy  \
# 0         X   8.64 liters per 100 km            6.14 L/100 km
# 1         E  27.27 liters per 100 km  30.76 liters per 100 km
# 2         Z              0.17 L/10km   2.03 liters per 100 km
# 3         X            6.52 km per L              1.59 L/10km
# 4         Z            20.15 L/100km              0.60 L/10km
#
#   Fuel Consumption Comb  CO2 Emissions(g/km)  numeric_FuelCity  \
# 0        37.59 mpg Imp.                306.0              8.64
# 1        28.84 L/100 km                283.0             27.27
# 2                  zero                329.0              0.17
# 3                   NaN                270.0              6.52
# 4           1.38 L/10km                193.0             20.15
#
#   MeasureUnit_FuelCity  numeric_FuelHwy MeasureUnit_FuelHwy  numeric_FuelComb  \
# 0    liters per 100 km             6.14            L/100 km             37.59
# 1    liters per 100 km            30.76   liters per 100 km             28.84
# 2               L/10km             2.03   liters per 100 km               NaN
# 3             km per L             1.59              L/10km               NaN
# 4              L/100km             0.60              L/10km              1.38
#
#   MeasureUnit_FuelComb
# 0             mpg Imp.
# 1             L/100 km
# 2                  NaN
# 3                  NaN
# 4               L/10km

# %% [markdown]
# #### L/100 km --> km/L

# %%
df_checking['numeric_FuelCity'] = np.where(df_train['MeasureUnit_FuelCity'] == 'L/100 km', 
                                           100 / df_train['numeric_FuelCity'], df_train['numeric_FuelCity'])
df_checking[df_checking['MeasureUnit_FuelCity'] == 'L/100 km'].head(3)
# Out:
#     Id   Make            Vehicle Class Engine Size(L) Cylinders  Transmission  \
# 36  37    BMV                  COMPACT            3.0       6.0            A8
# 40  41  CHEVO           SUV - STANDARD            5.3       8.0  not-recorded
# 42  43   FOLD  PICKUP TRUCK - STANDARD            3.5       6.0           AS6
#
#    Fuel Type Fuel Consumption City Fuel Consumption Hwy Fuel Consumption Comb  \
# 36         Z         1.54 L/100 km        6.85 MPG (AS)        14.43 MPG (AS)
# 40         X        13.70 L/100 km        1.72 L/100 km           0.83 L/10km
# 42         X        14.09 L/100 km        6.73 L/100 km                 -9999
#
#     CO2 Emissions(g/km)  numeric_FuelCity MeasureUnit_FuelCity  \
# 36                188.0         64.935065             L/100 km
# 40                338.0          7.299270             L/100 km
# 42                282.0          7.097232             L/100 km
#
#     numeric_FuelHwy MeasureUnit_FuelHwy  numeric_FuelComb MeasureUnit_FuelComb
# 36             6.85            MPG (AS)             14.43             MPG (AS)
# 40             1.72            L/100 km              0.83               L/10km
# 42             6.73            L/100 km           9999.00                  NaN

# %% [markdown]
# #### mpg Imp. --> km/L

# %%
df_checking['numeric_FuelCity'] = np.where(df_train['MeasureUnit_FuelCity'] == 'mpg Imp.', 
                                           0.354006 * df_train['numeric_FuelCity'], df_train['numeric_FuelCity'])
df_checking[df_checking['MeasureUnit_FuelCity'] == 'mpg Imp.'].head(3)
# Out:
#     Id   Make   Vehicle Class Engine Size(L) Cylinders Transmission Fuel Type  \
# 8    9  CHEVO  SUV - STANDARD            3.6       NaN           A9         X
# 16  17  CHEVO  SUV - STANDARD            5.3       NaN           A6         E
# 27  28    BMV       FULL-SIZE            4.4       NaN          AS8         Z
#
#    Fuel Consumption City Fuel Consumption Hwy    Fuel Consumption Comb  \
# 8          9.16 mpg Imp.          2.08 L/10km            26.31 L/100km
# 16        35.25 mpg Imp.        22.09 L/100km  14.35 liters per 100 km
# 27         9.96 mpg Imp.       12.33 L/100 km  21.15 liters per 100 km
#
#     CO2 Emissions(g/km)  numeric_FuelCity MeasureUnit_FuelCity  \
# 8                 278.0          3.242695             mpg Imp.
# 16                311.0         12.478711             mpg Imp.
# 27                295.0          3.525900             mpg Imp.
#
#     numeric_FuelHwy MeasureUnit_FuelHwy  numeric_FuelComb MeasureUnit_FuelComb
# 8              2.08              L/10km             26.31              L/100km
# 16            22.09             L/100km             14.35    liters per 100 km
# 27            12.33            L/100 km             21.15    liters per 100 km

# %% [markdown]
# #### liters per 100 km --> km/L

# %%
df_checking['numeric_FuelCity'] = np.where(df_train['MeasureUnit_FuelCity'] == 'liters per 100 km', 
                                           100 / df_train['numeric_FuelCity'], df_train['numeric_FuelCity'])
df_checking[df_checking['MeasureUnit_FuelCity'] == 'liters per 100 km'].head(3)
# Out:
#     Id    Make            Vehicle Class Engine Size(L) Cylinders Transmission  \
# 0    1    FOLD  PICKUP TRUCK - STANDARD            3.5       6.0           A6
# 1    2   CHEVO  PICKUP TRUCK - STANDARD            5.3       NaN           A6
# 10  11  TOYOTI              SUV - SMALL            2.5       4.0          AS6
#
#    Fuel Type    Fuel Consumption City     Fuel Consumption Hwy  \
# 0          X   8.64 liters per 100 km            6.14 L/100 km
# 1          E  27.27 liters per 100 km  30.76 liters per 100 km
# 10         X  27.73 liters per 100 km             2.27 L/100km
#
#    Fuel Consumption Comb  CO2 Emissions(g/km)  numeric_FuelCity  \
# 0         37.59 mpg Imp.                306.0         11.574074
# 1         28.84 L/100 km                283.0          3.667033
# 10                  zero                216.0          3.606203
#
#    MeasureUnit_FuelCity  numeric_FuelHwy MeasureUnit_FuelHwy  \
# 0     liters per 100 km             6.14            L/100 km
# 1     liters per 100 km            30.76   liters per 100 km
# 10    liters per 100 km             2.27             L/100km
#
#     numeric_FuelComb MeasureUnit_FuelComb
# 0              37.59             mpg Imp.
# 1              28.84             L/100 km
# 10               NaN                  NaN

# %% [markdown]
# MPG (AS) --> km/L

# %%
df_checking['numeric_FuelCity'] = np.where(df_train['MeasureUnit_FuelCity'] == 'MPG (AS)', 
                                           0.425143707 * df_train['numeric_FuelCity'], df_train['numeric_FuelCity'])
df_checking[df_checking['MeasureUnit_FuelCity'] == 'MPG (AS)'].head(3)
# Out:
#     Id          Make Vehicle Class Engine Size(L) Cylinders  Transmission  \
# 5    6         LECUS       COMPACT    unspecified       4.0  not-recorded
# 7    8  LAND CRAWLER   SUV - SMALL            2.0       4.0           AS8
# 28  29        BARUSU       COMPACT            NaN       4.0            AV
#
#    Fuel Type Fuel Consumption City     Fuel Consumption Hwy  \
# 5          Z         5.57 MPG (AS)           38.28 mpg Imp.
# 7          Z        28.55 MPG (AS)   2.06 liters per 100 km
# 28         X        32.72 MPG (AS)  31.16 liters per 100 km
#
#    Fuel Consumption Comb  CO2 Emissions(g/km)  numeric_FuelCity  \
# 5          8.86 MPG (AS)                217.0          2.368050
# 7             18.33 km/L                246.0         12.137853
# 28             5.56 km/L                165.0         13.910702
#
#    MeasureUnit_FuelCity  numeric_FuelHwy MeasureUnit_FuelHwy  \
# 5              MPG (AS)            38.28            mpg Imp.
# 7              MPG (AS)             2.06   liters per 100 km
# 28             MPG (AS)            31.16   liters per 100 km
#
#     numeric_FuelComb MeasureUnit_FuelComb
# 5               8.86             MPG (AS)
# 7              18.33                 km/L
# 28              5.56                 km/L

# %% [markdown]
# ### Make Function

# %%
def StandardizeUnitMeasure_City(data):
    data['numeric_FuelCity'] = np.where(data['MeasureUnit_FuelCity'] == 'L/10km', 10 / data['numeric_FuelCity'], data['numeric_FuelCity'])
    data['numeric_FuelCity'] = np.where(data['MeasureUnit_FuelCity'] == 'L/100km', 100 / data['numeric_FuelCity'], data['numeric_FuelCity'])
    data['numeric_FuelCity'] = np.where(data['MeasureUnit_FuelCity'] == 'L/100 km', 100 / data['numeric_FuelCity'], data['numeric_FuelCity'])
    data['numeric_FuelCity'] = np.where(data['MeasureUnit_FuelCity'] == 'mpg Imp.', 0.354006 * data['numeric_FuelCity'], data['numeric_FuelCity'])
    data['numeric_FuelCity'] = np.where(data['MeasureUnit_FuelCity'] == 'liters per 100 km', 100 / data['numeric_FuelCity'], data['numeric_FuelCity'])
    data['numeric_FuelCity'] = np.where(data['MeasureUnit_FuelCity'] == 'MPG (AS)', 0.425143707 * data['numeric_FuelCity'], data['numeric_FuelCity'])

    return data

# %%
def StandardizeUnitMeasure_Hwy(data):
    data['numeric_FuelHwy'] = np.where(data['MeasureUnit_FuelHwy'] == 'L/10km', 10 / data['numeric_FuelHwy'], data['numeric_FuelHwy'])
    data['numeric_FuelHwy'] = np.where(data['MeasureUnit_FuelHwy'] == 'L/100km', 100 / data['numeric_FuelHwy'], data['numeric_FuelHwy'])
    data['numeric_FuelHwy'] = np.where(data['MeasureUnit_FuelHwy'] == 'L/100 km', 100 / data['numeric_FuelHwy'], data['numeric_FuelHwy'])
    data['numeric_FuelHwy'] = np.where(data['MeasureUnit_FuelHwy'] == 'mpg Imp.', 0.354006 * data['numeric_FuelHwy'], data['numeric_FuelHwy'])
    data['numeric_FuelHwy'] = np.where(data['MeasureUnit_FuelHwy'] == 'liters per 100 km', 100 / data['numeric_FuelHwy'], data['numeric_FuelHwy'])
    data['numeric_FuelHwy'] = np.where(data['MeasureUnit_FuelHwy'] == 'MPG (AS)', 0.425143707 * data['numeric_FuelHwy'], data['numeric_FuelHwy'])

    return data

# %%
def StandardizeUnitMeasure_Comb(data):
    data['numeric_FuelComb'] = np.where(data['MeasureUnit_FuelComb'] == 'L/10km', 10 / data['numeric_FuelComb'], data['numeric_FuelComb'])
    data['numeric_FuelComb'] = np.where(data['MeasureUnit_FuelComb'] == 'L/100km', 100 / data['numeric_FuelComb'], data['numeric_FuelComb'])
    data['numeric_FuelComb'] = np.where(data['MeasureUnit_FuelComb'] == 'L/100 km', 100 / data['numeric_FuelComb'], data['numeric_FuelComb'])
    data['numeric_FuelComb'] = np.where(data['MeasureUnit_FuelComb'] == 'mpg Imp.', 0.354006 * data['numeric_FuelComb'], data['numeric_FuelComb'])
    data['numeric_FuelComb'] = np.where(data['MeasureUnit_FuelComb'] == 'liters per 100 km', 100 / data['numeric_FuelComb'], data['numeric_FuelComb'])
    data['numeric_FuelComb'] = np.where(data['MeasureUnit_FuelComb'] == 'MPG (AS)', 0.425143707 * data['numeric_FuelComb'], data['numeric_FuelComb'])

    return data

# %%
StandardizeUnitMeasure_City(df_train)
# Out:
#             Id    Make            Vehicle Class Engine Size(L) Cylinders  \
# 0            1    FOLD  PICKUP TRUCK - STANDARD            3.5       6.0
# 1            2   CHEVO  PICKUP TRUCK - STANDARD            5.3       NaN
# 2            3     BMV               SUBCOMPACT            4.4       NaN
# 3            4     KIO              SUV - SMALL            NaN       4.0
# 4            5  BARUSU              MINICOMPACT            3.0       6.0
# ...        ...     ...                      ...            ...       ...
# 137136  137137     BMV               SUBCOMPACT             na       8.0
# 137137  137138   GONDA    STATION WAGON - SMALL            1.5       4.0
# 137138  137139  NIRRAN                 MID-SIZE            1.8       4.0
# 137139  137140  TOYOTI                  COMPACT            1.8       4.0
# 137140  137141  BARUSU                 MID-SIZE            2.5       4.0
#
#        Transmission Fuel Type    Fuel Consumption City  \
# 0                A6         X   8.64 liters per 100 km
# 1                A6         E  27.27 liters per 100 km
# 2                M6         Z              0.17 L/10km
# 3               AS6         X            6.52 km per L
# 4       unspecified         Z            20.15 L/100km
# ...             ...       ...                      ...
# 137136          AS8         Z           33.71 L/100 km
# 137137           M6         X           15.41 km per L
# 137138           AV         X   2.99 liters per 100 km
# 137139           na         X            11.48 L/100km
# 137140          AV6         X   3.36 liters per 100 km
#
#            Fuel Consumption Hwy Fuel Consumption Comb  CO2 Emissions(g/km)  \
# 0                 6.14 L/100 km        37.59 mpg Imp.                306.0
# 1       30.76 liters per 100 km        28.84 L/100 km                283.0
# 2        2.03 liters per 100 km                  zero                329.0
# 3                   1.59 L/10km                   NaN                270.0
# 4                   0.60 L/10km           1.38 L/10km                193.0
# ...                         ...                   ...                  ...
# 137136           12.99 km per L         4.54 km per L                275.0
# 137137            0.87 L/100 km        59.38 MPG (AS)                166.0
# 137138            8.38 L/100 km        52.19 mpg Imp.                181.0
# 137139         1275.84 mpg Imp.           0.64 L/10km                123.0
# 137140              0.28 L/10km        32.27 km per L                182.0
#
#         numeric_FuelCity MeasureUnit_FuelCity  numeric_FuelHwy  \
# 0              11.574074    liters per 100 km             6.14
# 1               3.667033    liters per 100 km            30.76
# 2              58.823529               L/10km             2.03
# 3               6.520000             km per L             1.59
# 4               4.962779              L/100km             0.60
# ...                  ...                  ...              ...
# 137136          2.966479             L/100 km            12.99
# 137137         15.410000             km per L             0.87
# 137138         33.444816    liters per 100 km             8.38
# 137139          8.710801              L/100km          1275.84
# 137140         29.761905    liters per 100 km             0.28
#
#        MeasureUnit_FuelHwy  numeric_FuelComb MeasureUnit_FuelComb
# 0                 L/100 km             37.59             mpg Imp.
# 1        liters per 100 km             28.84             L/100 km
# 2        liters per 100 km               NaN                  NaN
# 3                   L/10km               NaN                  NaN
# 4                   L/10km              1.38               L/10km
# ...                    ...               ...                  ...
# 137136            km per L              4.54             km per L
# 137137            L/100 km             59.38             MPG (AS)
# 137138            L/100 km             52.19             mpg Imp.
# 137139            mpg Imp.              0.64               L/10km
# 137140              L/10km             32.27             km per L
#
# [137141 rows x 17 columns]

# %%
StandardizeUnitMeasure_Hwy(df_train)
# Out:
#             Id    Make            Vehicle Class Engine Size(L) Cylinders  \
# 0            1    FOLD  PICKUP TRUCK - STANDARD            3.5       6.0
# 1            2   CHEVO  PICKUP TRUCK - STANDARD            5.3       NaN
# 2            3     BMV               SUBCOMPACT            4.4       NaN
# 3            4     KIO              SUV - SMALL            NaN       4.0
# 4            5  BARUSU              MINICOMPACT            3.0       6.0
# ...        ...     ...                      ...            ...       ...
# 137136  137137     BMV               SUBCOMPACT             na       8.0
# 137137  137138   GONDA    STATION WAGON - SMALL            1.5       4.0
# 137138  137139  NIRRAN                 MID-SIZE            1.8       4.0
# 137139  137140  TOYOTI                  COMPACT            1.8       4.0
# 137140  137141  BARUSU                 MID-SIZE            2.5       4.0
#
#        Transmission Fuel Type    Fuel Consumption City  \
# 0                A6         X   8.64 liters per 100 km
# 1                A6         E  27.27 liters per 100 km
# 2                M6         Z              0.17 L/10km
# 3               AS6         X            6.52 km per L
# 4       unspecified         Z            20.15 L/100km
# ...             ...       ...                      ...
# 137136          AS8         Z           33.71 L/100 km
# 137137           M6         X           15.41 km per L
# 137138           AV         X   2.99 liters per 100 km
# 137139           na         X            11.48 L/100km
# 137140          AV6         X   3.36 liters per 100 km
#
#            Fuel Consumption Hwy Fuel Consumption Comb  CO2 Emissions(g/km)  \
# 0                 6.14 L/100 km        37.59 mpg Imp.                306.0
# 1       30.76 liters per 100 km        28.84 L/100 km                283.0
# 2        2.03 liters per 100 km                  zero                329.0
# 3                   1.59 L/10km                   NaN                270.0
# 4                   0.60 L/10km           1.38 L/10km                193.0
# ...                         ...                   ...                  ...
# 137136           12.99 km per L         4.54 km per L                275.0
# 137137            0.87 L/100 km        59.38 MPG (AS)                166.0
# 137138            8.38 L/100 km        52.19 mpg Imp.                181.0
# 137139         1275.84 mpg Imp.           0.64 L/10km                123.0
# 137140              0.28 L/10km        32.27 km per L                182.0
#
#         numeric_FuelCity MeasureUnit_FuelCity  numeric_FuelHwy  \
# 0              11.574074    liters per 100 km        16.286645
# 1               3.667033    liters per 100 km         3.250975
# 2              58.823529               L/10km        49.261084
# 3               6.520000             km per L         6.289308
# 4               4.962779              L/100km        16.666667
# ...                  ...                  ...              ...
# 137136          2.966479             L/100 km        12.990000
# 137137         15.410000             km per L       114.942529
# 137138         33.444816    liters per 100 km        11.933174
# 137139          8.710801              L/100km       451.655015
# 137140         29.761905    liters per 100 km        35.714286
#
#        MeasureUnit_FuelHwy  numeric_FuelComb MeasureUnit_FuelComb
# 0                 L/100 km             37.59             mpg Imp.
# 1        liters per 100 km             28.84             L/100 km
# 2        liters per 100 km               NaN                  NaN
# 3                   L/10km               NaN                  NaN
# 4                   L/10km              1.38               L/10km
# ...                    ...               ...                  ...
# 137136            km per L              4.54             km per L
# 137137            L/100 km             59.38             MPG (AS)
# 137138            L/100 km             52.19             mpg Imp.
# 137139            mpg Imp.              0.64               L/10km
# 137140              L/10km             32.27             km per L
#
# [137141 rows x 17 columns]

# %%
StandardizeUnitMeasure_Comb(df_train)
# Out:
#             Id    Make            Vehicle Class Engine Size(L) Cylinders  \
# 0            1    FOLD  PICKUP TRUCK - STANDARD            3.5       6.0
# 1            2   CHEVO  PICKUP TRUCK - STANDARD            5.3       NaN
# 2            3     BMV               SUBCOMPACT            4.4       NaN
# 3            4     KIO              SUV - SMALL            NaN       4.0
# 4            5  BARUSU              MINICOMPACT            3.0       6.0
# ...        ...     ...                      ...            ...       ...
# 137136  137137     BMV               SUBCOMPACT             na       8.0
# 137137  137138   GONDA    STATION WAGON - SMALL            1.5       4.0
# 137138  137139  NIRRAN                 MID-SIZE            1.8       4.0
# 137139  137140  TOYOTI                  COMPACT            1.8       4.0
# 137140  137141  BARUSU                 MID-SIZE            2.5       4.0
#
#        Transmission Fuel Type    Fuel Consumption City  \
# 0                A6         X   8.64 liters per 100 km
# 1                A6         E  27.27 liters per 100 km
# 2                M6         Z              0.17 L/10km
# 3               AS6         X            6.52 km per L
# 4       unspecified         Z            20.15 L/100km
# ...             ...       ...                      ...
# 137136          AS8         Z           33.71 L/100 km
# 137137           M6         X           15.41 km per L
# 137138           AV         X   2.99 liters per 100 km
# 137139           na         X            11.48 L/100km
# 137140          AV6         X   3.36 liters per 100 km
#
#            Fuel Consumption Hwy Fuel Consumption Comb  CO2 Emissions(g/km)  \
# 0                 6.14 L/100 km        37.59 mpg Imp.                306.0
# 1       30.76 liters per 100 km        28.84 L/100 km                283.0
# 2        2.03 liters per 100 km                  zero                329.0
# 3                   1.59 L/10km                   NaN                270.0
# 4                   0.60 L/10km           1.38 L/10km                193.0
# ...                         ...                   ...                  ...
# 137136           12.99 km per L         4.54 km per L                275.0
# 137137            0.87 L/100 km        59.38 MPG (AS)                166.0
# 137138            8.38 L/100 km        52.19 mpg Imp.                181.0
# 137139         1275.84 mpg Imp.           0.64 L/10km                123.0
# 137140              0.28 L/10km        32.27 km per L                182.0
#
#         numeric_FuelCity MeasureUnit_FuelCity  numeric_FuelHwy  \
# 0              11.574074    liters per 100 km        16.286645
# 1               3.667033    liters per 100 km         3.250975
# 2              58.823529               L/10km        49.261084
# 3               6.520000             km per L         6.289308
# 4               4.962779              L/100km        16.666667
# ...                  ...                  ...              ...
# 137136          2.966479             L/100 km        12.990000
# 137137         15.410000             km per L       114.942529
# 137138         33.444816    liters per 100 km        11.933174
# 137139          8.710801              L/100km       451.655015
# 137140         29.761905    liters per 100 km        35.714286
#
#        MeasureUnit_FuelHwy  numeric_FuelComb MeasureUnit_FuelComb
# 0                 L/100 km         13.307086             mpg Imp.
# 1        liters per 100 km          3.467406             L/100 km
# 2        liters per 100 km               NaN                  NaN
# 3                   L/10km               NaN                  NaN
# 4                   L/10km          7.246377               L/10km
# ...                    ...               ...                  ...
# 137136            km per L          4.540000             km per L
# 137137            L/100 km         25.245033             MPG (AS)
# 137138            L/100 km         18.475573             mpg Imp.
# 137139            mpg Imp.         15.625000               L/10km
# 137140              L/10km         32.270000             km per L
#
# [137141 rows x 17 columns]

# %% [markdown]
# ### Fill NaN Values

# %% [markdown]
# #### Fuel Consumption Columns

# %%
def Fill_Missing_Value_City(data):
    conditions = ['zero', 'not-available', '-9999', '-1', '0']

    data['numeric_FuelCity'] = np.where(data['Fuel Consumption City'].isin(conditions), 
                                        (data['numeric_FuelComb']-(0.45*data['numeric_FuelHwy']))/0.55, data['numeric_FuelCity'])

# %%
def Fill_Missing_Value_Hwy(data):
    conditions = ['zero', 'not-available', '-9999', '-1', '0']

    data['numeric_FuelHwy'] = np.where(data['Fuel Consumption Hwy'].isin(conditions), 
                                       (data['numeric_FuelComb']-(0.55*data['numeric_FuelCity']))/0.45, data['numeric_FuelHwy'])

# %%
def Fill_Missing_Value_Comb(data):
    data['numeric_FuelComb'] = np.where((data['Fuel Consumption City'].notna()) & (data['Fuel Consumption Hwy'].notna()), 
                                        (0.55*data['numeric_FuelCity']) + (0.45*data['numeric_FuelHwy']), data['numeric_FuelComb'])

# %%
def FillNa_Fuel(df_train):
    missing_city = df_train['numeric_FuelCity'].isna()
    df_train.loc[missing_city, 'numeric_FuelCity'] = (df_train['numeric_FuelComb'] - (0.45 * df_train['numeric_FuelHwy'])) / 0.55
    
    missing_hwy = df_train['numeric_FuelHwy'].isna()
    df_train.loc[missing_hwy, 'numeric_FuelHwy'] = (df_train['numeric_FuelComb'] - (0.55 * df_train['numeric_FuelCity'])) / 0.45

    missing_comb = df_train['numeric_FuelComb'].isna()
    df_train.loc[missing_comb, 'numeric_FuelComb'] = (df_train['numeric_FuelCity']*0.55) + (df_train['numeric_FuelHwy']*0.45)

# %%
df_train.isnull().sum()
# Out:
# Id                           0
# Make                         0
# Vehicle Class             1325
# Engine Size(L)           16619
# Cylinders                14155
# Transmission              2605
# Fuel Type                 1855
# Fuel Consumption City     2422
# Fuel Consumption Hwy      2568
# Fuel Consumption Comb     2582
# CO2 Emissions(g/km)          0
# numeric_FuelCity          3645
# MeasureUnit_FuelCity      6048
# numeric_FuelHwy           3887
# MeasureUnit_FuelHwy       6488
# numeric_FuelComb          3958
# MeasureUnit_FuelComb      6490
# dtype: int64

# %%
Fill_Missing_Value_City(df_train)
Fill_Missing_Value_Hwy(df_train)
Fill_Missing_Value_Comb(df_train)
FillNa_Fuel(df_train)

# %%
df_train.isnull().sum()
# Out:
# Id                           0
# Make                         0
# Vehicle Class             1325
# Engine Size(L)           16619
# Cylinders                14155
# Transmission              2605
# Fuel Type                 1855
# Fuel Consumption City     2422
# Fuel Consumption Hwy      2568
# Fuel Consumption Comb     2582
# CO2 Emissions(g/km)          0
# numeric_FuelCity           309
# MeasureUnit_FuelCity      6048
# numeric_FuelHwy            325
# MeasureUnit_FuelHwy       6488
# numeric_FuelComb           351
# MeasureUnit_FuelComb      6490
# dtype: int64

# %%
df_train[df_train["numeric_FuelComb"].isna()]
# Out:
#             Id     Make            Vehicle Class Engine Size(L)  \
# 197        198     JIPU              SUV - SMALL            NaN
# 344        345      KIO    STATION WAGON - SMALL            NaN
# 576        577      BMV               SUBCOMPACT            3.0
# 1311      1312      BMV               TWO-SEATER            2.0
# 1405      1406    MITSU                  COMPACT            2.4
# ...        ...      ...                      ...            ...
# 135286  135287     FOLD  PICKUP TRUCK - STANDARD            2.7
# 135528  135529     FOLD           SUV - STANDARD            3.5
# 135746  135747  RYUNDAI                  COMPACT            1.6
# 135878  135879     DOGE                FULL-SIZE            3.0
# 136216  136217    GONDA                FULL-SIZE            1.5
#
#             Cylinders Transmission Fuel Type Fuel Consumption City  \
# 197               6.0           A9         E                   NaN
# 344               4.0          AS6         X         not-available
# 576               6.0          AS8         Z                    -1
# 1311              4.0          AS8         Z        17.53 mpg Imp.
# 1405              4.0          AV6         X                    -1
# ...               ...          ...       ...                   ...
# 135286            6.0         AS10         X                 -9999
# 135528  unestablished          AS6         X        25.00 mpg Imp.
# 135746            4.0          AM7         X                 -9999
# 135878            6.0           A8         X         3.01 L/100 km
# 136216            4.0          AV7         X        56.62 MPG (AS)
#
#        Fuel Consumption Hwy Fuel Consumption Comb  CO2 Emissions(g/km)  \
# 197          15.86 mpg Imp.                   NaN                225.0
# 344          11.26 L/100 km                  zero                213.0
# 576          48.55 MPG (AS)         not-available                241.0
# 1311                    NaN                   NaN                205.0
# 1405          4.40 km per L         not-available                219.0
# ...                     ...                   ...                  ...
# 135286                  NaN                   NaN                251.0
# 135528        not-available                   NaN                308.0
# 135746       12.10 L/100 km                  zero                188.0
# 135878                  NaN                  zero                298.0
# 136216                  NaN                   NaN                176.0
#
#         numeric_FuelCity MeasureUnit_FuelCity  numeric_FuelHwy  \
# 197                  NaN                  NaN         5.614535
# 344                  NaN                  NaN         8.880995
# 576                  NaN                  NaN        20.640727
# 1311            6.205725             mpg Imp.              NaN
# 1405                 NaN                  NaN         4.400000
# ...                  ...                  ...              ...
# 135286               NaN                  NaN              NaN
# 135528          8.850150             mpg Imp.              NaN
# 135746               NaN                  NaN         8.264463
# 135878         33.222591             L/100 km              NaN
# 136216         24.071637             MPG (AS)              NaN
#
#        MeasureUnit_FuelHwy  numeric_FuelComb MeasureUnit_FuelComb
# 197               mpg Imp.               NaN                  NaN
# 344               L/100 km               NaN                  NaN
# 576               MPG (AS)               NaN                  NaN
# 1311                   NaN               NaN                  NaN
# 1405              km per L               NaN                  NaN
# ...                    ...               ...                  ...
# 135286                 NaN               NaN                  NaN
# 135528                 NaN               NaN                  NaN
# 135746            L/100 km               NaN                  NaN
# 135878                 NaN               NaN                  NaN
# 136216                 NaN               NaN                  NaN
#
# [351 rows x 17 columns]

# %%
df_train = df_train[['Id', 'Make', 'Vehicle Class', 'Engine Size(L)', 'Cylinders', 'Transmission', 'Fuel Type', 
                     'numeric_FuelCity', 'numeric_FuelHwy', 'numeric_FuelComb', 'CO2 Emissions(g/km)']]
df_train.head()
# Out:
#    Id    Make            Vehicle Class Engine Size(L) Cylinders Transmission  \
# 0   1    FOLD  PICKUP TRUCK - STANDARD            3.5       6.0           A6
# 1   2   CHEVO  PICKUP TRUCK - STANDARD            5.3       NaN           A6
# 2   3     BMV               SUBCOMPACT            4.4       NaN           M6
# 3   4     KIO              SUV - SMALL            NaN       4.0          AS6
# 4   5  BARUSU              MINICOMPACT            3.0       6.0  unspecified
#
#   Fuel Type  numeric_FuelCity  numeric_FuelHwy  numeric_FuelComb  \
# 0         X         11.574074        16.286645         13.694731
# 1         E          3.667033         3.250975          3.479807
# 2         Z         58.823529        49.261084         54.520429
# 3         X          6.520000         6.289308          6.416189
# 4         Z          4.962779        16.666667         10.229529
#
#    CO2 Emissions(g/km)
# 0                306.0
# 1                283.0
# 2                329.0
# 3                270.0
# 4                193.0

# %% [markdown]
# #### Rest of The Columns

# %%
def Replace_Value(data):
    conditions = ['not-recorded', 'missing', 'na', 'not-available', 'unspecified','unestablished','unknown','-1']
    data['Vehicle Class'] = np.where(data['Vehicle Class'].isin(conditions), "Missing", data['Vehicle Class'])
    data['Engine Size(L)'] = np.where(data['Engine Size(L)'].isin(conditions), np.nan, data['Engine Size(L)'])
    data['Cylinders'] = np.where(data['Cylinders'].isin(conditions), np.nan, data['Cylinders'])
    data['Transmission'] = np.where(data['Transmission'].isin(conditions), "Missing", data['Transmission'])
    data['Fuel Type'] = np.where(data['Fuel Type'].isin(conditions), "Missing", data['Fuel Type'])

# %%
def Fill_Na_Rest(data):
    data['Vehicle Class'] = np.where(data['Vehicle Class'].isna, "Missing", data['Vehicle Class'])
    data['Engine Size(L)'] = np.where(data['Engine Size(L)'].isna, 0, data['Engine Size(L)'])
    data['Cylinders'] = np.where(data['Cylinders'].isna, 0, data['Cylinders'])
    data['Transmission'] = np.where(data['Transmission'].isna, "Missing", data['Transmission'])
    data['Fuel Type'] = np.where(data['Fuel Type'].isna, "Missing", data['Fuel Type'])

# %%
Replace_Value(df_train)
# Out:
# C:\Users\GF63\AppData\Local\Temp\ipykernel_26856\767123711.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vehicle Class'] = np.where(data['Vehicle Class'].isin(conditions), "Missing", data['Vehicle Class'])
# C:\Users\GF63\AppData\Local\Temp\ipykernel_26856\767123711.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Engine Size(L)'] = np.where(data['Engine Size(L)'].isin(conditions), np.nan, data['Engine Size(L)'])
# C:\Users\GF63\AppData\Local\Temp\ipykernel_26856\767123711.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cylinders'] = np.where(data['Cylinders'].isin(conditions), np.nan, data['Cylinders'])
# C:\Users\GF63\AppData\Local\Temp\ipykernel_26856\767123711.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Transmission'] = np.where(data['Transmission'].isin(conditions), "Missing", data['Transmission'])
# C:\Users\GF63\AppData\Local\Temp\ipykernel_26856\767123711.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Fuel Type'] = np.where(data['Fuel Type'].isin(conditions), "Missing", data['Fuel Type'])

# %% [markdown]
# # EDA

# %%
df_train.isnull().sum()
# Out:
# Id                         0
# Make                       0
# Vehicle Class           1325
# Engine Size(L)         24333
# Cylinders              20605
# Transmission            2605
# Fuel Type               1855
# numeric_FuelCity         309
# numeric_FuelHwy          325
# numeric_FuelComb         351
# CO2 Emissions(g/km)        0
# dtype: int64

# %%
Fill_Na_Rest(df_train)
# Out:
# C:\Users\GF63\AppData\Local\Temp\ipykernel_26856\479892910.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vehicle Class'] = np.where(data['Vehicle Class'].isna, "Missing", data['Vehicle Class'])
# C:\Users\GF63\AppData\Local\Temp\ipykernel_26856\479892910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Engine Size(L)'] = np.where(data['Engine Size(L)'].isna, 0, data['Engine Size(L)'])
# C:\Users\GF63\AppData\Local\Temp\ipykernel_26856\479892910.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cylinders'] = np.where(data['Cylinders'].isna, 0, data['Cylinders'])
# C:\Users\GF63\AppData\Local\Temp\ipykernel_26856\479892910.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Transmission'] = np.where(data['Transmission'].isna, "Missing", data['Transmission'])
# C:\Users\GF63\AppData\Local\Temp\ipykernel_26856\479892910.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Fuel Type'] = np.where(data['Fuel Type'].isna, "Missing", data['Fuel Type'])

# %%
df_train.isnull().sum()
# Out:
# Id                       0
# Make                     0
# Vehicle Class            0
# Engine Size(L)           0
# Cylinders                0
# Transmission             0
# Fuel Type                0
# numeric_FuelCity       309
# numeric_FuelHwy        325
# numeric_FuelComb       351
# CO2 Emissions(g/km)      0
# dtype: int64

# %%
df_train.shape
# Out:
# (137141, 11)
